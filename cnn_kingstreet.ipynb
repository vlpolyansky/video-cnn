# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from PIL import Image
import tensorflow as tf
import os
import pandas as pd
import numpy
import random as rand

# %%
def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)
        
def randfloat(a, b):
    return rand.random() * (b - a) + a

def my_print(s):
    sys.stdout.write(s)
    sys.stdout.flush()

# %%
data_dir = "./data/kingstreet/frames/001/"
save_dir = "./save_ks"
save_file_path = "./save_ks/model.ckpt"
logs_dir = "./logs_ks"
# logs_dir_2 = "./logs2"

create_dir(save_dir)
create_dir(logs_dir)
# create_dir(logs_dir_2)

BATCH_SIZE = 16
IMAGE_SHAPE = [405, 720, 3]

frames_cnt = len(os.listdir(data_dir))

_debug_list = []

# %%
def _create_label_producers():
    
    lines = [os.path.join(data_dir, str(i) + ".png") + " " + os.path.join(data_dir, str(i + 1) + ".png") + " 1"
             if rand.randint(0, 1) == 0 else 
             os.path.join(data_dir, str(i + 1) + ".png") + " " + os.path.join(data_dir, str(i) + ".png") + " 0"
             
             for i in xrange(frames_cnt - 1)]
    
    cnt = len(lines)
    p = 0.9
    train_cnt = int(cnt * p)
    print "Total: %i images, train: %i" % (cnt, train_cnt)
    train_lines = lines[:train_cnt]
    test_lines = lines[train_cnt:]
    return tf.train.string_input_producer(train_lines), tf.train.string_input_producer(test_lines)

def _read_image_and_label(path_label_line):
    with tf.name_scope("read_image_and_label"):
        path1, path2, label_str = tf.decode_csv(path_label_line, [[""], [""], [""]], field_delim=" ")
        label = tf.cast(tf.string_to_number(label_str, out_type=tf.int32), tf.int64)
        file_content1 = tf.read_file(path1)
        file_content2 = tf.read_file(path2)
        image1 = tf.image.decode_png(file_content1)
        image2 = tf.image.decode_png(file_content2)
        image1 = tf.cast(image1, tf.float32)
        image2 = tf.cast(image2, tf.float32)
        image1.set_shape(IMAGE_SHAPE)
        image2.set_shape(IMAGE_SHAPE)
    return image1, image2, label

def _generate_batch(image1, image2, label, batch_size, min_after_dequeue=200):
    with tf.name_scope("generate_batch"):
        images1, images2, labels = tf.train.shuffle_batch([image1, image2, label], batch_size=batch_size, 
                                                capacity=min_after_dequeue + batch_size * 4, 
                                                min_after_dequeue=min_after_dequeue,
                                                num_threads=5)
    return images1, images2, tf.reshape(labels, [batch_size])
    
def get_data_batch():
    train_queue, test_queue = _create_label_producers()
    image1_train, image2_train, label_train = _read_image_and_label(train_queue.dequeue())
    image1_test, image2_test, label_test = _read_image_and_label(test_queue.dequeue())
    images1_train, images2_train, labels_train = _generate_batch(image1_train, image2_train, 
                                                                 label_train, BATCH_SIZE)
    images1_test, images2_test, labels_test = _generate_batch(image1_test, image2_test, 
                                                              label_test, BATCH_SIZE,
                                                              min_after_dequeue=BATCH_SIZE)
    return images1_train, images2_train, labels_train, images1_test, images2_test, labels_test

def dense_to_one_hot(label_batch, num_labels=2):
    with tf.name_scope("one_hot_encoder"):
        sparse_labels = tf.cast(tf.reshape(label_batch, [-1, 1]), tf.int32)
        derived_size = tf.shape(sparse_labels)[0]
        indices = tf.reshape(tf.range(0, derived_size, 1), [-1, 1])
        concated = tf.concat(1, [indices, sparse_labels])
        outshape = tf.concat(0, [tf.reshape(derived_size, [1]), tf.reshape(num_labels, [1])])
        labels = tf.sparse_to_dense(concated, outshape, 1.0, 0.0)
        labels = tf.cast(labels, tf.float32)
    return labels

# %%
def _activation_summary(x):
    tensor_name = x.op.name
    tf.histogram_summary(tensor_name + '/activations', x)
    tf.scalar_summary(tensor_name + '/sparsity', tf.nn.zero_fraction(x))


def _create_conv(layer, kernel_shape, kernel_stddev=1e-3, activation=tf.nn.relu, name="conv", trainable=True):
    with tf.name_scope(name):
        kernel = tf.Variable(tf.truncated_normal(kernel_shape, stddev=kernel_stddev), name="kernel", 
                             trainable=trainable)
        tf.add_to_collection('main', kernel)
        conv = tf.nn.conv2d(layer, kernel, strides=[1, 1, 1, 1], padding="SAME")
        biases = tf.Variable(tf.constant(0.0, shape=[kernel_shape[3]]), name="biases", trainable=trainable)
        tf.add_to_collection('main', biases)
        biased = tf.nn.bias_add(conv, biases)
        conv_relu = activation(biased)
        _activation_summary(conv_relu)

    return conv_relu
    
def _create_pool(layer, kernel_width, stride=1, name="pool"):
    with tf.name_scope(name):
        pool = tf.nn.max_pool(layer, ksize=[1, kernel_width, kernel_width, 1], strides=[1, stride, stride, 1],
                             padding='SAME')
    return pool

def _create_norm(layer, name="norm"):
    with tf.name_scope(name):
        norm = tf.nn.lrn(layer, alpha=0.001 / 9.0, beta=0.75)
    return norm

def _create_full(layer, result_size, weights_stddev=.04, activation=tf.nn.relu, name="full", trainable=True):
    with tf.name_scope(name):
        layer_size = 1
        for k in layer.get_shape()[1:].as_list():
            layer_size *= k
        reshaped = tf.reshape(layer, [BATCH_SIZE, layer_size])
        weights = tf.Variable(tf.truncated_normal([layer_size, result_size], stddev=weights_stddev), name="weights",
                             trainable=trainable)
        tf.add_to_collection('main', weights)
        biases = tf.Variable(tf.constant(.1, shape=[result_size]), name="biases", trainable=trainable)
        tf.add_to_collection('main', biases)
        if activation:
            biased = tf.add(tf.matmul(reshaped, weights), biases)
            result = activation(biased)
        else:
            result = tf.add(tf.matmul(reshaped, weights), biases)
        
        _activation_summary(result)
    return result
    
def build_classifier(images1, images2, trainable=True):
    images = tf.concat(3, [images1, images2])
    
    conv1 = _create_conv(images, [7, 7, 6, 8], name="conv1", trainable=trainable)
    pool1 = _create_pool(conv1, 3, 2, name="pool1")
    norm1 = _create_norm(pool1, name="norm1")
    
    conv2 = _create_conv(norm1, [5, 5, 8, 16], name="conv2", trainable=trainable)
    pool2 = _create_pool(conv2, 3, 2, name="pool2")
    norm2 = _create_norm(pool2, name="norm2")
    
    conv3 = _create_conv(norm2, [5, 5, 16, 16], name="conv3", trainable=trainable)
    pool3 = _create_pool(conv3, 3, 2, name="pool3")
#     norm3 = _create_norm(pool3, name="norm3")
    
    full1 = _create_full(pool3, 128, name="full1", activation=tf.nn.relu, trainable=trainable)
    full2 = _create_full(full1, 64, name="full2", activation=tf.nn.relu, trainable=trainable)
    full3 = _create_full(full2, 2, name="full3", activation=None, trainable=trainable)
    
    softmax = tf.nn.softmax(full3, name="softmax")
    
    return softmax

# %%
def build_loss(logits, labels):
    with tf.name_scope("cross_entropy"):
        labels = tf.cast(labels, tf.int64)
        dense_labels = dense_to_one_hot(labels)
        clipped_logits = tf.clip_by_value(logits, 0.00001, 100.0)
        cross_entropy = -dense_labels * tf.log(clipped_logits)
#         cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits, dense_labels, 
#                                                                 name='cross_entropy_per_example')
        cross_entropy_mean = tf.reduce_mean(cross_entropy, name='cross_entropy')

    return cross_entropy_mean

# %%
def build_train(loss_op, step, init_rate=0.1, decay_steps=8000):

    with tf.name_scope("train"):
        learning_rate = tf.train.exponential_decay(init_rate, step, decay_steps, 0.1, staircase=True)
        optimizer = tf.train.GradientDescentOptimizer(learning_rate)
        grads = optimizer.compute_gradients(loss_op)

        apply_gradient_op = optimizer.apply_gradients(grads, global_step=step)

        for var in tf.trainable_variables():
            tf.histogram_summary(var.op.name, var)

        for grad, var in grads:
            if grad:
                tf.histogram_summary(var.op.name + '/gradients', grad)

    return apply_gradient_op

# %%
def load(saver, sess):
    saver.restore(sess, save_file_path)
    print "Model restored."
    
def save(saver, sess):
    save_path = saver.save(sess, save_file_path)
    print "Model saved in file: %s" % save_path

def train_classifier(need_load):
    global _debug_list
    _debug_list = []
    N = 50000
    
    with tf.Graph().as_default() as g: 
        
        step = tf.Variable(0, trainable=False, name="step")
        tf.add_to_collection("main", step)
    
        images1_train, images2_train, labels_train, images1_test, images2_test, labels_test = get_data_batch()
        images1_ph = tf.placeholder(tf.float32, [BATCH_SIZE] + IMAGE_SHAPE, "images1")
        images2_ph = tf.placeholder(tf.float32, [BATCH_SIZE] + IMAGE_SHAPE, "images2")
        labels_ph = tf.placeholder(tf.int64, [BATCH_SIZE], "labels")
        answer_op = build_classifier(images1_ph, images2_ph, trainable=True)
        loss_op = build_loss(answer_op, labels_ph)
        train_op = build_train(loss_op, step)
        correct_prediction = tf.equal(tf.argmax(answer_op, 1), labels_ph)
        accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
        accuracy_summary = tf.scalar_summary("accuracy", accuracy)

        merged_summaries = tf.merge_all_summaries()

        init = tf.initialize_all_variables()

        sess = tf.Session(config=tf.ConfigProto(log_device_placement=False))
        saver = tf.train.Saver(var_list=tf.get_collection("main"))
        coord = tf.train.Coordinator()
        writer = tf.train.SummaryWriter(logs_dir, sess.graph_def, flush_secs=30)

        sess.run(init)
        threads = tf.train.start_queue_runners(sess=sess, coord=coord)

        try:

            if need_load:
                load(saver, sess)

            my_print("Starting...\n")

            for i in xrange(0, N):
                if i % 11 == 0:
                    im1, im2, lab = sess.run([images1_test, images2_test, labels_test])
                    feed = {
                        images1_ph : im1,
                        images2_ph : im2,
                        labels_ph : lab
                    }
                    result = sess.run([merged_summaries, accuracy, step], feed_dict=feed)
                    summary_str = result[0]
                    acc = result[1]
                    st = result[2]
                    writer.add_summary(summary_str, st)
                    print("Accuracy at step %s: %s" % (st, acc))
                else:
                    im1, im2, lab = sess.run([images1_train, images2_train, labels_train])
                    feed = {
                        images1_ph : im1,
                        images2_ph : im2,
                        labels_ph : lab
                    }
                    sess.run(train_op, feed_dict=feed)

                if i % 100 == 0:
                    save(saver, sess)
        finally:
            coord.request_stop()
            coord.join(threads)

# %% [raw]
# def pair_loss(images1, images2):
#     return tf.constant(0, dtype=tf.float32)

# %% [raw]
# def gen_image():
#     N = 20000
#
#     with tf.Graph().as_default() as g:
#
#         step = tf.Variable(0, trainable=False, name="step_2")
#
#         _, _, _, images1_test, _, labels_test = get_data_batch()
#         images1_ph = tf.placeholder(tf.float32, [BATCH_SIZE] + IMAGE_SHAPE, "images1")
# #         images2 = tf.Variable(tf.random_uniform([BATCH_SIZE] + IMAGE_SHAPE, 0, 1), "images2")
#         images2 = tf.Variable(tf.constant(0, tf.float32, [BATCH_SIZE] + IMAGE_SHAPE), "images2")
# #         images2 = tf.Variable(images1_ph, "images2")
#         tf.image_summary("given", images1_ph)
#         tf.image_summary("generated", images2)
#         labels_ph = tf.placeholder(tf.int64, [BATCH_SIZE], "labels")
#         answer_op = build_classifier(images1_ph, images2, trainable=False)
#         l_loss = build_loss(answer_op, labels_ph)
#         p_loss = pair_loss(images1_ph, images2)
#         tf.scalar_summary("l_loss", l_loss)
#         tf.scalar_summary("p_loss", p_loss)
#         loss_op = l_loss + p_loss
#         train_op = build_train(loss_op, step, init_rate=10., decay_steps=5000)
#         correct_prediction = tf.equal(tf.argmax(answer_op, 1), labels_ph)
#         accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
#         accuracy_summary = tf.scalar_summary("accuracy", accuracy)
#
#         merged_summaries = tf.merge_all_summaries()
#
#         init = tf.initialize_all_variables()
#
#         sess = tf.Session(config=tf.ConfigProto(log_device_placement=False))
#         saver = tf.train.Saver(var_list=tf.get_collection("main"))
#         coord = tf.train.Coordinator()
#         writer = tf.train.SummaryWriter(logs_dir_2, sess.graph_def, flush_secs=30)
#
#         sess.run(init)
#         threads = tf.train.start_queue_runners(sess=sess, coord=coord)
#
#
#         im1, lab = sess.run([images1_test, labels_test])
#         feed = {
#             images1_ph : im1,
#             labels_ph : lab
#         }
#
#         sess.run(tf.assign(images2, images1_ph), feed_dict=feed)
#
#         try:
#
#             load(saver, sess)
#
#             my_print("Starting...\n")
#
#             for i in xrange(N):
#                 if i % 11 == 0:
#                     result = sess.run([merged_summaries, accuracy, step], feed_dict=feed)
#                     summary_str = result[0]
#                     acc = result[1]
#                     st = result[2]
#                     writer.add_summary(summary_str, st)
#                     print("Accuracy at step %s: %s" % (st, acc))
#                 else:
#                     sess.run(train_op, feed_dict=feed)
#         finally:
#             coord.request_stop()
#             coord.join(threads)

# %%
train_classifier(need_load=False)
# Out:
# Total: 128709 images, train: 115838
# Starting...
# Accuracy at step 0: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 10: 0.3125
# Accuracy at step 20: 0.6875
# Accuracy at step 30: 0.5
# Accuracy at step 40: 0.5
# Accuracy at step 50: 0.3125
# Accuracy at step 60: 0.25
# Accuracy at step 70: 0.5
# Accuracy at step 80: 0.5
# Accuracy at step 90: 0.625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 100: 0.5
# Accuracy at step 110: 0.375
# Accuracy at step 120: 0.375
# Accuracy at step 130: 0.3125
# Accuracy at step 140: 0.6875
# Accuracy at step 150: 0.5
# Accuracy at step 160: 0.5
# Accuracy at step 170: 0.4375
# Accuracy at step 180: 0.625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 190: 0.5625
# Accuracy at step 200: 0.25
# Accuracy at step 210: 0.3125
# Accuracy at step 220: 0.4375
# Accuracy at step 230: 0.5
# Accuracy at step 240: 0.6875
# Accuracy at step 250: 0.4375
# Accuracy at step 260: 0.4375
# Accuracy at step 270: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 280: 0.375
# Accuracy at step 290: 0.5
# Accuracy at step 300: 0.625
# Accuracy at step 310: 0.4375
# Accuracy at step 320: 0.4375
# Accuracy at step 330: 0.5
# Accuracy at step 340: 0.4375
# Accuracy at step 350: 0.625
# Accuracy at step 360: 0.6875
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 370: 0.375
# Accuracy at step 380: 0.4375
# Accuracy at step 390: 0.5
# Accuracy at step 400: 0.5625
# Accuracy at step 410: 0.4375
# Accuracy at step 420: 0.5
# Accuracy at step 430: 0.5625
# Accuracy at step 440: 0.4375
# Accuracy at step 450: 0.5
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 460: 0.625
# Accuracy at step 470: 0.5625
# Accuracy at step 480: 0.1875
# Accuracy at step 490: 0.5
# Accuracy at step 500: 0.5
# Accuracy at step 510: 0.4375
# Accuracy at step 520: 0.5
# Accuracy at step 530: 0.625
# Accuracy at step 540: 0.5
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 550: 0.5
# Accuracy at step 560: 0.4375
# Accuracy at step 570: 0.4375
# Accuracy at step 580: 0.3125
# Accuracy at step 590: 0.6875
# Accuracy at step 600: 0.6875
# Accuracy at step 610: 0.5
# Accuracy at step 620: 0.5
# Accuracy at step 630: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 640: 0.3125
# Accuracy at step 650: 0.4375
# Accuracy at step 660: 0.4375
# Accuracy at step 670: 0.4375
# Accuracy at step 680: 0.5
# Accuracy at step 690: 0.625
# Accuracy at step 700: 0.25
# Accuracy at step 710: 0.5
# Accuracy at step 720: 0.4375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 730: 0.375
# Accuracy at step 740: 0.625
# Accuracy at step 750: 0.4375
# Accuracy at step 760: 0.5
# Accuracy at step 770: 0.375
# Accuracy at step 780: 0.5
# Accuracy at step 790: 0.6875
# Accuracy at step 800: 0.625
# Accuracy at step 810: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 820: 0.625
# Accuracy at step 830: 0.4375
# Accuracy at step 840: 0.5
# Accuracy at step 850: 0.6875
# Accuracy at step 860: 0.4375
# Accuracy at step 870: 0.875
# Accuracy at step 880: 0.25
# Accuracy at step 890: 0.4375
# Accuracy at step 900: 0.3125
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 910: 0.5
# Accuracy at step 920: 0.6875
# Accuracy at step 930: 0.5
# Accuracy at step 940: 0.5625
# Accuracy at step 950: 0.375
# Accuracy at step 960: 0.5
# Accuracy at step 970: 0.375
# Accuracy at step 980: 0.625
# Accuracy at step 990: 0.375
# Accuracy at step 1000: 0.5
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 1010: 0.375
# Accuracy at step 1020: 0.75
# Accuracy at step 1030: 0.5625
# Accuracy at step 1040: 0.625
# Accuracy at step 1050: 0.5625
# Accuracy at step 1060: 0.375
# Accuracy at step 1070: 0.5625
# Accuracy at step 1080: 0.5625
# Accuracy at step 1090: 0.4375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 1100: 0.5625
# Accuracy at step 1110: 0.5
# Accuracy at step 1120: 0.625
# Accuracy at step 1130: 0.5625
# Accuracy at step 1140: 0.625
# Accuracy at step 1150: 0.5
# Accuracy at step 1160: 0.5
# Accuracy at step 1170: 0.375
# Accuracy at step 1180: 0.625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 1190: 0.75
# Accuracy at step 1200: 0.6875
# Accuracy at step 1210: 0.5
# Accuracy at step 1220: 0.6875
# Accuracy at step 1230: 0.3125
# Accuracy at step 1240: 0.8125
# Accuracy at step 1250: 0.5
# Accuracy at step 1260: 0.5
# Accuracy at step 1270: 0.5
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 1280: 0.5625
# Accuracy at step 1290: 0.75
# Accuracy at step 1300: 0.4375
# Accuracy at step 1310: 0.4375
# Accuracy at step 1320: 0.75
# Accuracy at step 1330: 0.8125
# Accuracy at step 1340: 0.6875
# Accuracy at step 1350: 0.4375
# Accuracy at step 1360: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 1370: 0.5
# Accuracy at step 1380: 0.6875
# Accuracy at step 1390: 0.4375
# Accuracy at step 1400: 0.375
# Accuracy at step 1410: 0.5625
# Accuracy at step 1420: 0.4375
# Accuracy at step 1430: 0.5
# Accuracy at step 1440: 0.4375
# Accuracy at step 1450: 0.375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 1460: 0.5
# Accuracy at step 1470: 0.4375
# Accuracy at step 1480: 0.3125
# Accuracy at step 1490: 0.5625
# Accuracy at step 1500: 0.375
# Accuracy at step 1510: 0.375
# Accuracy at step 1520: 0.5
# Accuracy at step 1530: 0.625
# Accuracy at step 1540: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 1550: 0.375
# Accuracy at step 1560: 0.5625
# Accuracy at step 1570: 0.5
# Accuracy at step 1580: 0.375
# Accuracy at step 1590: 0.5
# Accuracy at step 1600: 0.5625
# Accuracy at step 1610: 0.4375
# Accuracy at step 1620: 0.625
# Accuracy at step 1630: 0.3125
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 1640: 0.5
# Accuracy at step 1650: 0.625
# Accuracy at step 1660: 0.6875
# Accuracy at step 1670: 0.6875
# Accuracy at step 1680: 0.3125
# Accuracy at step 1690: 0.375
# Accuracy at step 1700: 0.375
# Accuracy at step 1710: 0.5625
# Accuracy at step 1720: 0.4375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 1730: 0.375
# Accuracy at step 1740: 0.5
# Accuracy at step 1750: 0.4375
# Accuracy at step 1760: 0.625
# Accuracy at step 1770: 0.625
# Accuracy at step 1780: 0.625
# Accuracy at step 1790: 0.625
# Accuracy at step 1800: 0.4375
# Accuracy at step 1810: 0.4375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 1820: 0.4375
# Accuracy at step 1830: 0.375
# Accuracy at step 1840: 0.375
# Accuracy at step 1850: 0.4375
# Accuracy at step 1860: 0.3125
# Accuracy at step 1870: 0.4375
# Accuracy at step 1880: 0.625
# Accuracy at step 1890: 0.6875
# Accuracy at step 1900: 0.3125
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 1910: 0.4375
# Accuracy at step 1920: 0.625
# Accuracy at step 1930: 0.625
# Accuracy at step 1940: 0.5
# Accuracy at step 1950: 0.5
# Accuracy at step 1960: 0.5
# Accuracy at step 1970: 0.5
# Accuracy at step 1980: 0.625
# Accuracy at step 1990: 0.3125
# Accuracy at step 2000: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 2010: 0.3125
# Accuracy at step 2020: 0.5625
# Accuracy at step 2030: 0.625
# Accuracy at step 2040: 0.5625
# Accuracy at step 2050: 0.375
# Accuracy at step 2060: 0.4375
# Accuracy at step 2070: 0.5
# Accuracy at step 2080: 0.375
# Accuracy at step 2090: 0.625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 2100: 0.5
# Accuracy at step 2110: 0.5625
# Accuracy at step 2120: 0.875
# Accuracy at step 2130: 0.5
# Accuracy at step 2140: 0.5625
# Accuracy at step 2150: 0.5
# Accuracy at step 2160: 0.4375
# Accuracy at step 2170: 0.4375
# Accuracy at step 2180: 0.375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 2190: 0.4375
# Accuracy at step 2200: 0.5
# Accuracy at step 2210: 0.6875
# Accuracy at step 2220: 0.25
# Accuracy at step 2230: 0.625
# Accuracy at step 2240: 0.375
# Accuracy at step 2250: 0.75
# Accuracy at step 2260: 0.375
# Accuracy at step 2270: 0.3125
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 2280: 0.25
# Accuracy at step 2290: 0.3125
# Accuracy at step 2300: 0.625
# Accuracy at step 2310: 0.4375
# Accuracy at step 2320: 0.6875
# Accuracy at step 2330: 0.4375
# Accuracy at step 2340: 0.5
# Accuracy at step 2350: 0.5
# Accuracy at step 2360: 0.5
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 2370: 0.5
# Accuracy at step 2380: 0.375
# Accuracy at step 2390: 0.5
# Accuracy at step 2400: 0.4375
# Accuracy at step 2410: 0.4375
# Accuracy at step 2420: 0.5
# Accuracy at step 2430: 0.625
# Accuracy at step 2440: 0.375
# Accuracy at step 2450: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 2460: 0.5
# Accuracy at step 2470: 0.625
# Accuracy at step 2480: 0.375
# Accuracy at step 2490: 0.5
# Accuracy at step 2500: 0.4375
# Accuracy at step 2510: 0.3125
# Accuracy at step 2520: 0.4375
# Accuracy at step 2530: 0.375
# Accuracy at step 2540: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 2550: 0.4375
# Accuracy at step 2560: 0.5625
# Accuracy at step 2570: 0.625
# Accuracy at step 2580: 0.375
# Accuracy at step 2590: 0.5625
# Accuracy at step 2600: 0.375
# Accuracy at step 2610: 0.4375
# Accuracy at step 2620: 0.5
# Accuracy at step 2630: 0.5
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 2640: 0.5
# Accuracy at step 2650: 0.4375
# Accuracy at step 2660: 0.5625
# Accuracy at step 2670: 0.5625
# Accuracy at step 2680: 0.375
# Accuracy at step 2690: 0.4375
# Accuracy at step 2700: 0.5
# Accuracy at step 2710: 0.5
# Accuracy at step 2720: 0.5
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 2730: 0.625
# Accuracy at step 2740: 0.375
# Accuracy at step 2750: 0.3125
# Accuracy at step 2760: 0.4375
# Accuracy at step 2770: 0.5
# Accuracy at step 2780: 0.625
# Accuracy at step 2790: 0.375
# Accuracy at step 2800: 0.5625
# Accuracy at step 2810: 0.75
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 2820: 0.5
# Accuracy at step 2830: 0.875
# Accuracy at step 2840: 0.6875
# Accuracy at step 2850: 0.5625
# Accuracy at step 2860: 0.375
# Accuracy at step 2870: 0.5625
# Accuracy at step 2880: 0.75
# Accuracy at step 2890: 0.5
# Accuracy at step 2900: 0.5
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 2910: 0.375
# Accuracy at step 2920: 0.5
# Accuracy at step 2930: 0.5625
# Accuracy at step 2940: 0.5
# Accuracy at step 2950: 0.4375
# Accuracy at step 2960: 0.125
# Accuracy at step 2970: 0.5
# Accuracy at step 2980: 0.4375
# Accuracy at step 2990: 0.5625
# Accuracy at step 3000: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 3010: 0.625
# Accuracy at step 3020: 0.6875
# Accuracy at step 3030: 0.4375
# Accuracy at step 3040: 0.5
# Accuracy at step 3050: 0.5
# Accuracy at step 3060: 0.5625
# Accuracy at step 3070: 0.4375
# Accuracy at step 3080: 0.5625
# Accuracy at step 3090: 0.8125
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 3100: 0.4375
# Accuracy at step 3110: 0.5
# Accuracy at step 3120: 0.8125
# Accuracy at step 3130: 0.4375
# Accuracy at step 3140: 0.375
# Accuracy at step 3150: 0.4375
# Accuracy at step 3160: 0.5
# Accuracy at step 3170: 0.5625
# Accuracy at step 3180: 0.4375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 3190: 0.4375
# Accuracy at step 3200: 0.4375
# Accuracy at step 3210: 0.25
# Accuracy at step 3220: 0.5
# Accuracy at step 3230: 0.5
# Accuracy at step 3240: 0.5
# Accuracy at step 3250: 0.4375
# Accuracy at step 3260: 0.5
# Accuracy at step 3270: 0.375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 3280: 0.375
# Accuracy at step 3290: 0.25
# Accuracy at step 3300: 0.5
# Accuracy at step 3310: 0.4375
# Accuracy at step 3320: 0.25
# Accuracy at step 3330: 0.4375
# Accuracy at step 3340: 0.25
# Accuracy at step 3350: 0.5
# Accuracy at step 3360: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 3370: 0.5625
# Accuracy at step 3380: 0.375
# Accuracy at step 3390: 0.125
# Accuracy at step 3400: 0.25
# Accuracy at step 3410: 0.4375
# Accuracy at step 3420: 0.4375
# Accuracy at step 3430: 0.375
# Accuracy at step 3440: 0.375
# Accuracy at step 3450: 0.375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 3460: 0.5
# Accuracy at step 3470: 0.5625
# Accuracy at step 3480: 0.5625
# Accuracy at step 3490: 0.625
# Accuracy at step 3500: 0.5625
# Accuracy at step 3510: 0.375
# Accuracy at step 3520: 0.5625
# Accuracy at step 3530: 0.5
# Accuracy at step 3540: 0.375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 3550: 0.5
# Accuracy at step 3560: 0.5
# Accuracy at step 3570: 0.5625
# Accuracy at step 3580: 0.5625
# Accuracy at step 3590: 0.3125
# Accuracy at step 3600: 0.4375
# Accuracy at step 3610: 0.6875
# Accuracy at step 3620: 0.6875
# Accuracy at step 3630: 0.6875
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 3640: 0.6875
# Accuracy at step 3650: 0.375
# Accuracy at step 3660: 0.375
# Accuracy at step 3670: 0.375
# Accuracy at step 3680: 0.625
# Accuracy at step 3690: 0.625
# Accuracy at step 3700: 0.75
# Accuracy at step 3710: 0.4375
# Accuracy at step 3720: 0.5
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 3730: 0.5625
# Accuracy at step 3740: 0.625
# Accuracy at step 3750: 0.4375
# Accuracy at step 3760: 0.375
# Accuracy at step 3770: 0.3125
# Accuracy at step 3780: 0.25
# Accuracy at step 3790: 0.5
# Accuracy at step 3800: 0.5
# Accuracy at step 3810: 0.6875
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 3820: 0.4375
# Accuracy at step 3830: 0.5
# Accuracy at step 3840: 0.4375
# Accuracy at step 3850: 0.375
# Accuracy at step 3860: 0.5625
# Accuracy at step 3870: 0.5625
# Accuracy at step 3880: 0.625
# Accuracy at step 3890: 0.375
# Accuracy at step 3900: 0.4375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 3910: 0.5
# Accuracy at step 3920: 0.375
# Accuracy at step 3930: 0.4375
# Accuracy at step 3940: 0.5
# Accuracy at step 3950: 0.5625
# Accuracy at step 3960: 0.25
# Accuracy at step 3970: 0.375
# Accuracy at step 3980: 0.3125
# Accuracy at step 3990: 0.25
# Accuracy at step 4000: 0.5
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 4010: 0.5
# Accuracy at step 4020: 0.625
# Accuracy at step 4030: 0.625
# Accuracy at step 4040: 0.6875
# Accuracy at step 4050: 0.4375
# Accuracy at step 4060: 0.4375
# Accuracy at step 4070: 0.5625
# Accuracy at step 4080: 0.5
# Accuracy at step 4090: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 4100: 0.5
# Accuracy at step 4110: 0.4375
# Accuracy at step 4120: 0.4375
# Accuracy at step 4130: 0.4375
# Accuracy at step 4140: 0.4375
# Accuracy at step 4150: 0.5625
# Accuracy at step 4160: 0.5
# Accuracy at step 4170: 0.375
# Accuracy at step 4180: 0.6875
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 4190: 0.4375
# Accuracy at step 4200: 0.375
# Accuracy at step 4210: 0.3125
# Accuracy at step 4220: 0.5
# Accuracy at step 4230: 0.6875
# Accuracy at step 4240: 0.625
# Accuracy at step 4250: 0.4375
# Accuracy at step 4260: 0.5
# Accuracy at step 4270: 0.75
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 4280: 0.75
# Accuracy at step 4290: 0.4375
# Accuracy at step 4300: 0.4375
# Accuracy at step 4310: 0.5
# Accuracy at step 4320: 0.4375
# Accuracy at step 4330: 0.4375
# Accuracy at step 4340: 0.5625
# Accuracy at step 4350: 0.375
# Accuracy at step 4360: 0.5
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 4370: 0.625
# Accuracy at step 4380: 0.625
# Accuracy at step 4390: 0.4375
# Accuracy at step 4400: 0.5
# Accuracy at step 4410: 0.5625
# Accuracy at step 4420: 0.4375
# Accuracy at step 4430: 0.4375
# Accuracy at step 4440: 0.625
# Accuracy at step 4450: 0.625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 4460: 0.5625
# Accuracy at step 4470: 0.375
# Accuracy at step 4480: 0.375
# Accuracy at step 4490: 0.3125
# Accuracy at step 4500: 0.375
# Accuracy at step 4510: 0.625
# Accuracy at step 4520: 0.625
# Accuracy at step 4530: 0.375
# Accuracy at step 4540: 0.75
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 4550: 0.375
# Accuracy at step 4560: 0.5
# Accuracy at step 4570: 0.375
# Accuracy at step 4580: 0.4375
# Accuracy at step 4590: 0.375
# Accuracy at step 4600: 0.5
# Accuracy at step 4610: 0.4375
# Accuracy at step 4620: 0.5625
# Accuracy at step 4630: 0.6875
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 4640: 0.8125
# Accuracy at step 4650: 0.4375
# Accuracy at step 4660: 0.4375
# Accuracy at step 4670: 0.5
# Accuracy at step 4680: 0.3125
# Accuracy at step 4690: 0.5
# Accuracy at step 4700: 0.5625
# Accuracy at step 4710: 0.625
# Accuracy at step 4720: 0.6875
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 4730: 0.5
# Accuracy at step 4740: 0.3125
# Accuracy at step 4750: 0.6875
# Accuracy at step 4760: 0.5
# Accuracy at step 4770: 0.6875
# Accuracy at step 4780: 0.5625
# Accuracy at step 4790: 0.5
# Accuracy at step 4800: 0.375
# Accuracy at step 4810: 0.5
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 4820: 0.5
# Accuracy at step 4830: 0.625
# Accuracy at step 4840: 0.5625
# Accuracy at step 4850: 0.75
# Accuracy at step 4860: 0.6875
# Accuracy at step 4870: 0.25
# Accuracy at step 4880: 0.5625
# Accuracy at step 4890: 0.4375
# Accuracy at step 4900: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 4910: 0.4375
# Accuracy at step 4920: 0.75
# Accuracy at step 4930: 0.4375
# Accuracy at step 4940: 0.4375
# Accuracy at step 4950: 0.625
# Accuracy at step 4960: 0.375
# Accuracy at step 4970: 0.5
# Accuracy at step 4980: 0.5
# Accuracy at step 4990: 0.625
# Accuracy at step 5000: 0.4375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 5010: 0.4375
# Accuracy at step 5020: 0.5625
# Accuracy at step 5030: 0.8125
# Accuracy at step 5040: 0.4375
# Accuracy at step 5050: 0.3125
# Accuracy at step 5060: 0.375
# Accuracy at step 5070: 0.5625
# Accuracy at step 5080: 0.625
# Accuracy at step 5090: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 5100: 0.25
# Accuracy at step 5110: 0.3125
# Accuracy at step 5120: 0.4375
# Accuracy at step 5130: 0.5625
# Accuracy at step 5140: 0.75
# Accuracy at step 5150: 0.375
# Accuracy at step 5160: 0.375
# Accuracy at step 5170: 0.5625
# Accuracy at step 5180: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 5190: 0.5625
# Accuracy at step 5200: 0.625
# Accuracy at step 5210: 0.5
# Accuracy at step 5220: 0.5
# Accuracy at step 5230: 0.4375
# Accuracy at step 5240: 0.6875
# Accuracy at step 5250: 0.5
# Accuracy at step 5260: 0.5625
# Accuracy at step 5270: 0.75
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 5280: 0.625
# Accuracy at step 5290: 0.75
# Accuracy at step 5300: 0.5
# Accuracy at step 5310: 0.375
# Accuracy at step 5320: 0.4375
# Accuracy at step 5330: 0.5625
# Accuracy at step 5340: 0.5625
# Accuracy at step 5350: 0.3125
# Accuracy at step 5360: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 5370: 0.5
# Accuracy at step 5380: 0.3125
# Accuracy at step 5390: 0.5
# Accuracy at step 5400: 0.625
# Accuracy at step 5410: 0.5
# Accuracy at step 5420: 0.375
# Accuracy at step 5430: 0.5625
# Accuracy at step 5440: 0.625
# Accuracy at step 5450: 0.25
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 5460: 0.5
# Accuracy at step 5470: 0.625
# Accuracy at step 5480: 0.5625
# Accuracy at step 5490: 0.5625
# Accuracy at step 5500: 0.375
# Accuracy at step 5510: 0.5625
# Accuracy at step 5520: 0.375
# Accuracy at step 5530: 0.5625
# Accuracy at step 5540: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 5550: 0.5625
# Accuracy at step 5560: 0.6875
# Accuracy at step 5570: 0.375
# Accuracy at step 5580: 0.5625
# Accuracy at step 5590: 0.375
# Accuracy at step 5600: 0.5625
# Accuracy at step 5610: 0.5
# Accuracy at step 5620: 0.625
# Accuracy at step 5630: 0.625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 5640: 0.125
# Accuracy at step 5650: 0.5
# Accuracy at step 5660: 0.375
# Accuracy at step 5670: 0.375
# Accuracy at step 5680: 0.6875
# Accuracy at step 5690: 0.5625
# Accuracy at step 5700: 0.5625
# Accuracy at step 5710: 0.625
# Accuracy at step 5720: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 5730: 0.5
# Accuracy at step 5740: 0.4375
# Accuracy at step 5750: 0.4375
# Accuracy at step 5760: 0.5
# Accuracy at step 5770: 0.4375
# Accuracy at step 5780: 0.5
# Accuracy at step 5790: 0.375
# Accuracy at step 5800: 0.3125
# Accuracy at step 5810: 0.4375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 5820: 0.25
# Accuracy at step 5830: 0.4375
# Accuracy at step 5840: 0.625
# Accuracy at step 5850: 0.3125
# Accuracy at step 5860: 0.625
# Accuracy at step 5870: 0.375
# Accuracy at step 5880: 0.4375
# Accuracy at step 5890: 0.4375
# Accuracy at step 5900: 0.375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 5910: 0.4375
# Accuracy at step 5920: 0.5
# Accuracy at step 5930: 0.4375
# Accuracy at step 5940: 0.4375
# Accuracy at step 5950: 0.5625
# Accuracy at step 5960: 0.5
# Accuracy at step 5970: 0.3125
# Accuracy at step 5980: 0.5625
# Accuracy at step 5990: 0.375
# Accuracy at step 6000: 0.4375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 6010: 0.6875
# Accuracy at step 6020: 0.5
# Accuracy at step 6030: 0.5625
# Accuracy at step 6040: 0.5625
# Accuracy at step 6050: 0.5625
# Accuracy at step 6060: 0.5625
# Accuracy at step 6070: 0.6875
# Accuracy at step 6080: 0.375
# Accuracy at step 6090: 0.3125
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 6100: 0.75
# Accuracy at step 6110: 0.625
# Accuracy at step 6120: 0.25
# Accuracy at step 6130: 0.375
# Accuracy at step 6140: 0.5625
# Accuracy at step 6150: 0.4375
# Accuracy at step 6160: 0.4375
# Accuracy at step 6170: 0.5625
# Accuracy at step 6180: 0.4375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 6190: 0.5625
# Accuracy at step 6200: 0.5625
# Accuracy at step 6210: 0.6875
# Accuracy at step 6220: 0.5625
# Accuracy at step 6230: 0.3125
# Accuracy at step 6240: 0.5625
# Accuracy at step 6250: 0.375
# Accuracy at step 6260: 0.3125
# Accuracy at step 6270: 0.25
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 6280: 0.6875
# Accuracy at step 6290: 0.5
# Accuracy at step 6300: 0.375
# Accuracy at step 6310: 0.3125
# Accuracy at step 6320: 0.25
# Accuracy at step 6330: 0.4375
# Accuracy at step 6340: 0.5
# Accuracy at step 6350: 0.5625
# Accuracy at step 6360: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 6370: 0.5625
# Accuracy at step 6380: 0.375
# Accuracy at step 6390: 0.6875
# Accuracy at step 6400: 0.375
# Accuracy at step 6410: 0.625
# Accuracy at step 6420: 0.5
# Accuracy at step 6430: 0.5625
# Accuracy at step 6440: 0.5625
# Accuracy at step 6450: 0.4375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 6460: 0.4375
# Accuracy at step 6470: 0.3125
# Accuracy at step 6480: 0.4375
# Accuracy at step 6490: 0.4375
# Accuracy at step 6500: 0.375
# Accuracy at step 6510: 0.4375
# Accuracy at step 6520: 0.375
# Accuracy at step 6530: 0.75
# Accuracy at step 6540: 0.6875
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 6550: 0.625
# Accuracy at step 6560: 0.4375
# Accuracy at step 6570: 0.4375
# Accuracy at step 6580: 0.3125
# Accuracy at step 6590: 0.5
# Accuracy at step 6600: 0.5
# Accuracy at step 6610: 0.5625
# Accuracy at step 6620: 0.5
# Accuracy at step 6630: 0.6875
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 6640: 0.625
# Accuracy at step 6650: 0.5625
# Accuracy at step 6660: 0.5
# Accuracy at step 6670: 0.5
# Accuracy at step 6680: 0.6875
# Accuracy at step 6690: 0.4375
# Accuracy at step 6700: 0.5
# Accuracy at step 6710: 0.375
# Accuracy at step 6720: 0.25
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 6730: 0.5625
# Accuracy at step 6740: 0.5
# Accuracy at step 6750: 0.4375
# Accuracy at step 6760: 0.5
# Accuracy at step 6770: 0.75
# Accuracy at step 6780: 0.5625
# Accuracy at step 6790: 0.5
# Accuracy at step 6800: 0.3125
# Accuracy at step 6810: 0.375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 6820: 0.375
# Accuracy at step 6830: 0.375
# Accuracy at step 6840: 0.5
# Accuracy at step 6850: 0.4375
# Accuracy at step 6860: 0.4375
# Accuracy at step 6870: 0.625
# Accuracy at step 6880: 0.3125
# Accuracy at step 6890: 0.3125
# Accuracy at step 6900: 0.5
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 6910: 0.4375
# Accuracy at step 6920: 0.625
# Accuracy at step 6930: 0.75
# Accuracy at step 6940: 0.3125
# Accuracy at step 6950: 0.625
# Accuracy at step 6960: 0.1875
# Accuracy at step 6970: 0.6875
# Accuracy at step 6980: 0.5
# Accuracy at step 6990: 0.375
# Accuracy at step 7000: 0.3125
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 7010: 0.375
# Accuracy at step 7020: 0.75
# Accuracy at step 7030: 0.375
# Accuracy at step 7040: 0.5625
# Accuracy at step 7050: 0.5625
# Accuracy at step 7060: 0.375
# Accuracy at step 7070: 0.4375
# Accuracy at step 7080: 0.4375
# Accuracy at step 7090: 0.625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 7100: 0.375
# Accuracy at step 7110: 0.5625
# Accuracy at step 7120: 0.5625
# Accuracy at step 7130: 0.375
# Accuracy at step 7140: 0.375
# Accuracy at step 7150: 0.25
# Accuracy at step 7160: 0.3125
# Accuracy at step 7170: 0.5
# Accuracy at step 7180: 0.375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 7190: 0.625
# Accuracy at step 7200: 0.375
# Accuracy at step 7210: 0.625
# Accuracy at step 7220: 0.5
# Accuracy at step 7230: 0.5625
# Accuracy at step 7240: 0.25
# Accuracy at step 7250: 0.4375
# Accuracy at step 7260: 0.625
# Accuracy at step 7270: 0.625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 7280: 0.375
# Accuracy at step 7290: 0.5
# Accuracy at step 7300: 0.5625
# Accuracy at step 7310: 0.5625
# Accuracy at step 7320: 0.4375
# Accuracy at step 7330: 0.6875
# Accuracy at step 7340: 0.375
# Accuracy at step 7350: 0.4375
# Accuracy at step 7360: 0.5
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 7370: 0.4375
# Accuracy at step 7380: 0.5625
# Accuracy at step 7390: 0.3125
# Accuracy at step 7400: 0.25
# Accuracy at step 7410: 0.625
# Accuracy at step 7420: 0.75
# Accuracy at step 7430: 0.5
# Accuracy at step 7440: 0.4375
# Accuracy at step 7450: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 7460: 0.4375
# Accuracy at step 7470: 0.5
# Accuracy at step 7480: 0.3125
# Accuracy at step 7490: 0.5625
# Accuracy at step 7500: 0.5625
# Accuracy at step 7510: 0.5
# Accuracy at step 7520: 0.375
# Accuracy at step 7530: 0.5
# Accuracy at step 7540: 0.375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 7550: 0.4375
# Accuracy at step 7560: 0.3125
# Accuracy at step 7570: 0.375
# Accuracy at step 7580: 0.625
# Accuracy at step 7590: 0.5
# Accuracy at step 7600: 0.625
# Accuracy at step 7610: 0.5
# Accuracy at step 7620: 0.5
# Accuracy at step 7630: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 7640: 0.375
# Accuracy at step 7650: 0.375
# Accuracy at step 7660: 0.4375
# Accuracy at step 7670: 0.5
# Accuracy at step 7680: 0.625
# Accuracy at step 7690: 0.1875
# Accuracy at step 7700: 0.6875
# Accuracy at step 7710: 0.5625
# Accuracy at step 7720: 0.625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 7730: 0.5625
# Accuracy at step 7740: 0.375
# Accuracy at step 7750: 0.4375
# Accuracy at step 7760: 0.3125
# Accuracy at step 7770: 0.5
# Accuracy at step 7780: 0.5625
# Accuracy at step 7790: 0.5
# Accuracy at step 7800: 0.625
# Accuracy at step 7810: 0.4375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 7820: 0.5
# Accuracy at step 7830: 0.6875
# Accuracy at step 7840: 0.375
# Accuracy at step 7850: 0.5
# Accuracy at step 7860: 0.5625
# Accuracy at step 7870: 0.5
# Accuracy at step 7880: 0.5625
# Accuracy at step 7890: 0.625
# Accuracy at step 7900: 0.6875
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 7910: 0.625
# Accuracy at step 7920: 0.5625
# Accuracy at step 7930: 0.6875
# Accuracy at step 7940: 0.375
# Accuracy at step 7950: 0.5
# Accuracy at step 7960: 0.5
# Accuracy at step 7970: 0.5625
# Accuracy at step 7980: 0.5625
# Accuracy at step 7990: 0.4375
# Accuracy at step 8000: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 8010: 0.625
# Accuracy at step 8020: 0.4375
# Accuracy at step 8030: 0.5625
# Accuracy at step 8040: 0.5625
# Accuracy at step 8050: 0.4375
# Accuracy at step 8060: 0.5
# Accuracy at step 8070: 0.4375
# Accuracy at step 8080: 0.25
# Accuracy at step 8090: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 8100: 0.375
# Accuracy at step 8110: 0.6875
# Accuracy at step 8120: 0.4375
# Accuracy at step 8130: 0.5625
# Accuracy at step 8140: 0.375
# Accuracy at step 8150: 0.6875
# Accuracy at step 8160: 0.375
# Accuracy at step 8170: 0.3125
# Accuracy at step 8180: 0.5
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 8190: 0.3125
# Accuracy at step 8200: 0.5
# Accuracy at step 8210: 0.25
# Accuracy at step 8220: 0.5
# Accuracy at step 8230: 0.375
# Accuracy at step 8240: 0.5
# Accuracy at step 8250: 0.75
# Accuracy at step 8260: 0.625
# Accuracy at step 8270: 0.75
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 8280: 0.4375
# Accuracy at step 8290: 0.3125
# Accuracy at step 8300: 0.4375
# Accuracy at step 8310: 0.625
# Accuracy at step 8320: 0.5
# Accuracy at step 8330: 0.5625
# Accuracy at step 8340: 0.25
# Accuracy at step 8350: 0.375
# Accuracy at step 8360: 0.375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 8370: 0.3125
# Accuracy at step 8380: 0.4375
# Accuracy at step 8390: 0.5
# Accuracy at step 8400: 0.5625
# Accuracy at step 8410: 0.8125
# Accuracy at step 8420: 0.375
# Accuracy at step 8430: 0.5
# Accuracy at step 8440: 0.5
# Accuracy at step 8450: 0.625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 8460: 0.4375
# Accuracy at step 8470: 0.5625
# Accuracy at step 8480: 0.4375
# Accuracy at step 8490: 0.5625
# Accuracy at step 8500: 0.5625
# Accuracy at step 8510: 0.5
# Accuracy at step 8520: 0.4375
# Accuracy at step 8530: 0.5625
# Accuracy at step 8540: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 8550: 0.5
# Accuracy at step 8560: 0.375
# Accuracy at step 8570: 0.625
# Accuracy at step 8580: 0.4375
# Accuracy at step 8590: 0.5
# Accuracy at step 8600: 0.3125
# Accuracy at step 8610: 0.4375
# Accuracy at step 8620: 0.4375
# Accuracy at step 8630: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 8640: 0.25
# Accuracy at step 8650: 0.6875
# Accuracy at step 8660: 0.375
# Accuracy at step 8670: 0.5
# Accuracy at step 8680: 0.75
# Accuracy at step 8690: 0.375
# Accuracy at step 8700: 0.5
# Accuracy at step 8710: 0.4375
# Accuracy at step 8720: 0.5
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 8730: 0.625
# Accuracy at step 8740: 0.5625
# Accuracy at step 8750: 0.4375
# Accuracy at step 8760: 0.5
# Accuracy at step 8770: 0.4375
# Accuracy at step 8780: 0.6875
# Accuracy at step 8790: 0.5
# Accuracy at step 8800: 0.4375
# Accuracy at step 8810: 0.375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 8820: 0.5625
# Accuracy at step 8830: 0.5
# Accuracy at step 8840: 0.4375
# Accuracy at step 8850: 0.5
# Accuracy at step 8860: 0.5625
# Accuracy at step 8870: 0.375
# Accuracy at step 8880: 0.75
# Accuracy at step 8890: 0.5625
# Accuracy at step 8900: 0.625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 8910: 0.3125
# Accuracy at step 8920: 0.4375
# Accuracy at step 8930: 0.625
# Accuracy at step 8940: 0.875
# Accuracy at step 8950: 0.625
# Accuracy at step 8960: 0.625
# Accuracy at step 8970: 0.5625
# Accuracy at step 8980: 0.6875
# Accuracy at step 8990: 0.5625
# Accuracy at step 9000: 0.4375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 9010: 0.3125
# Accuracy at step 9020: 0.625
# Accuracy at step 9030: 0.6875
# Accuracy at step 9040: 0.6875
# Accuracy at step 9050: 0.4375
# Accuracy at step 9060: 0.3125
# Accuracy at step 9070: 0.625
# Accuracy at step 9080: 0.375
# Accuracy at step 9090: 0.5
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 9100: 0.5625
# Accuracy at step 9110: 0.6875
# Accuracy at step 9120: 0.4375
# Accuracy at step 9130: 0.5625
# Accuracy at step 9140: 0.5625
# Accuracy at step 9150: 0.625
# Accuracy at step 9160: 0.625
# Accuracy at step 9170: 0.625
# Accuracy at step 9180: 0.4375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 9190: 0.4375
# Accuracy at step 9200: 0.4375
# Accuracy at step 9210: 0.5625
# Accuracy at step 9220: 0.4375
# Accuracy at step 9230: 0.625
# Accuracy at step 9240: 0.5625
# Accuracy at step 9250: 0.4375
# Accuracy at step 9260: 0.5
# Accuracy at step 9270: 0.4375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 9280: 0.4375
# Accuracy at step 9290: 0.375
# Accuracy at step 9300: 0.5
# Accuracy at step 9310: 0.5
# Accuracy at step 9320: 0.3125
# Accuracy at step 9330: 0.375
# Accuracy at step 9340: 0.625
# Accuracy at step 9350: 0.5
# Accuracy at step 9360: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 9370: 0.4375
# Accuracy at step 9380: 0.5
# Accuracy at step 9390: 0.75
# Accuracy at step 9400: 0.6875
# Accuracy at step 9410: 0.5
# Accuracy at step 9420: 0.25
# Accuracy at step 9430: 0.5625
# Accuracy at step 9440: 0.625
# Accuracy at step 9450: 0.625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 9460: 0.4375
# Accuracy at step 9470: 0.625
# Accuracy at step 9480: 0.4375
# Accuracy at step 9490: 0.625
# Accuracy at step 9500: 0.1875
# Accuracy at step 9510: 0.375
# Accuracy at step 9520: 0.25
# Accuracy at step 9530: 0.5625
# Accuracy at step 9540: 0.5
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 9550: 0.6875
# Accuracy at step 9560: 0.25
# Accuracy at step 9570: 0.5625
# Accuracy at step 9580: 0.625
# Accuracy at step 9590: 0.625
# Accuracy at step 9600: 0.4375
# Accuracy at step 9610: 0.4375
# Accuracy at step 9620: 0.625
# Accuracy at step 9630: 0.4375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 9640: 0.5625
# Accuracy at step 9650: 0.375
# Accuracy at step 9660: 0.625
# Accuracy at step 9670: 0.625
# Accuracy at step 9680: 0.4375
# Accuracy at step 9690: 0.25
# Accuracy at step 9700: 0.5625
# Accuracy at step 9710: 0.3125
# Accuracy at step 9720: 0.625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 9730: 0.6875
# Accuracy at step 9740: 0.4375
# Accuracy at step 9750: 0.3125
# Accuracy at step 9760: 0.75
# Accuracy at step 9770: 0.6875
# Accuracy at step 9780: 0.375
# Accuracy at step 9790: 0.5
# Accuracy at step 9800: 0.5625
# Accuracy at step 9810: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 9820: 0.5625
# Accuracy at step 9830: 0.5
# Accuracy at step 9840: 0.4375
# Accuracy at step 9850: 0.4375
# Accuracy at step 9860: 0.5
# Accuracy at step 9870: 0.5625
# Accuracy at step 9880: 0.3125
# Accuracy at step 9890: 0.4375
# Accuracy at step 9900: 0.375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 9910: 0.625
# Accuracy at step 9920: 0.3125
# Accuracy at step 9930: 0.5625
# Accuracy at step 9940: 0.4375
# Accuracy at step 9950: 0.5625
# Accuracy at step 9960: 0.5
# Accuracy at step 9970: 0.375
# Accuracy at step 9980: 0.5625
# Accuracy at step 9990: 0.5
# Accuracy at step 10000: 0.5
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 10010: 0.4375
# Accuracy at step 10020: 0.4375
# Accuracy at step 10030: 0.625
# Accuracy at step 10040: 0.625
# Accuracy at step 10050: 0.5
# Accuracy at step 10060: 0.5625
# Accuracy at step 10070: 0.8125
# Accuracy at step 10080: 0.5
# Accuracy at step 10090: 0.6875
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 10100: 0.4375
# Accuracy at step 10110: 0.5
# Accuracy at step 10120: 0.5625
# Accuracy at step 10130: 0.5
# Accuracy at step 10140: 0.3125
# Accuracy at step 10150: 0.4375
# Accuracy at step 10160: 0.3125
# Accuracy at step 10170: 0.5625
# Accuracy at step 10180: 0.625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 10190: 0.5625
# Accuracy at step 10200: 0.375
# Accuracy at step 10210: 0.5
# Accuracy at step 10220: 0.5
# Accuracy at step 10230: 0.375
# Accuracy at step 10240: 0.25
# Accuracy at step 10250: 0.375
# Accuracy at step 10260: 0.5
# Accuracy at step 10270: 0.5
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 10280: 0.625
# Accuracy at step 10290: 0.5
# Accuracy at step 10300: 0.5625
# Accuracy at step 10310: 0.625
# Accuracy at step 10320: 0.6875
# Accuracy at step 10330: 0.375
# Accuracy at step 10340: 0.5
# Accuracy at step 10350: 0.625
# Accuracy at step 10360: 0.6875
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 10370: 0.3125
# Accuracy at step 10380: 0.375
# Accuracy at step 10390: 0.4375
# Accuracy at step 10400: 0.5625
# Accuracy at step 10410: 0.5625
# Accuracy at step 10420: 0.4375
# Accuracy at step 10430: 0.625
# Accuracy at step 10440: 0.375
# Accuracy at step 10450: 0.4375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 10460: 0.6875
# Accuracy at step 10470: 0.5
# Accuracy at step 10480: 0.625
# Accuracy at step 10490: 0.375
# Accuracy at step 10500: 0.4375
# Accuracy at step 10510: 0.5
# Accuracy at step 10520: 0.625
# Accuracy at step 10530: 0.5625
# Accuracy at step 10540: 0.625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 10550: 0.625
# Accuracy at step 10560: 0.4375
# Accuracy at step 10570: 0.25
# Accuracy at step 10580: 0.5
# Accuracy at step 10590: 0.75
# Accuracy at step 10600: 0.625
# Accuracy at step 10610: 0.5
# Accuracy at step 10620: 0.6875
# Accuracy at step 10630: 0.4375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 10640: 0.625
# Accuracy at step 10650: 0.4375
# Accuracy at step 10660: 0.625
# Accuracy at step 10670: 0.4375
# Accuracy at step 10680: 0.5
# Accuracy at step 10690: 0.5625
# Accuracy at step 10700: 0.5
# Accuracy at step 10710: 0.6875
# Accuracy at step 10720: 0.75
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 10730: 0.5
# Accuracy at step 10740: 0.4375
# Accuracy at step 10750: 0.4375
# Accuracy at step 10760: 0.4375
# Accuracy at step 10770: 0.375
# Accuracy at step 10780: 0.5
# Accuracy at step 10790: 0.5
# Accuracy at step 10800: 0.3125
# Accuracy at step 10810: 0.4375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 10820: 0.4375
# Accuracy at step 10830: 0.4375
# Accuracy at step 10840: 0.3125
# Accuracy at step 10850: 0.5
# Accuracy at step 10860: 0.4375
# Accuracy at step 10870: 0.4375
# Accuracy at step 10880: 0.375
# Accuracy at step 10890: 0.5625
# Accuracy at step 10900: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 10910: 0.625
# Accuracy at step 10920: 0.6875
# Accuracy at step 10930: 0.75
# Accuracy at step 10940: 0.5
# Accuracy at step 10950: 0.5625
# Accuracy at step 10960: 0.4375
# Accuracy at step 10970: 0.4375
# Accuracy at step 10980: 0.75
# Accuracy at step 10990: 0.375
# Accuracy at step 11000: 0.4375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 11010: 0.5625
# Accuracy at step 11020: 0.75
# Accuracy at step 11030: 0.5
# Accuracy at step 11040: 0.75
# Accuracy at step 11050: 0.5
# Accuracy at step 11060: 0.625
# Accuracy at step 11070: 0.5
# Accuracy at step 11080: 0.625
# Accuracy at step 11090: 0.375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 11100: 0.6875
# Accuracy at step 11110: 0.5
# Accuracy at step 11120: 0.5
# Accuracy at step 11130: 0.5
# Accuracy at step 11140: 0.1875
# Accuracy at step 11150: 0.5
# Accuracy at step 11160: 0.625
# Accuracy at step 11170: 0.3125
# Accuracy at step 11180: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 11190: 0.25
# Accuracy at step 11200: 0.375
# Accuracy at step 11210: 0.5
# Accuracy at step 11220: 0.5625
# Accuracy at step 11230: 0.5
# Accuracy at step 11240: 0.5625
# Accuracy at step 11250: 0.6875
# Accuracy at step 11260: 0.5625
# Accuracy at step 11270: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 11280: 0.5
# Accuracy at step 11290: 0.5625
# Accuracy at step 11300: 0.4375
# Accuracy at step 11310: 0.5
# Accuracy at step 11320: 0.5625
# Accuracy at step 11330: 0.4375
# Accuracy at step 11340: 0.5625
# Accuracy at step 11350: 0.4375
# Accuracy at step 11360: 0.375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 11370: 0.6875
# Accuracy at step 11380: 0.5625
# Accuracy at step 11390: 0.4375
# Accuracy at step 11400: 0.625
# Accuracy at step 11410: 0.5625
# Accuracy at step 11420: 0.375
# Accuracy at step 11430: 0.5
# Accuracy at step 11440: 0.375
# Accuracy at step 11450: 0.4375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 11460: 0.5625
# Accuracy at step 11470: 0.5625
# Accuracy at step 11480: 0.625
# Accuracy at step 11490: 0.4375
# Accuracy at step 11500: 0.6875
# Accuracy at step 11510: 0.6875
# Accuracy at step 11520: 0.4375
# Accuracy at step 11530: 0.5
# Accuracy at step 11540: 0.4375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 11550: 0.25
# Accuracy at step 11560: 0.5625
# Accuracy at step 11570: 0.6875
# Accuracy at step 11580: 0.375
# Accuracy at step 11590: 0.375
# Accuracy at step 11600: 0.4375
# Accuracy at step 11610: 0.5
# Accuracy at step 11620: 0.5625
# Accuracy at step 11630: 0.5
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 11640: 0.4375
# Accuracy at step 11650: 0.625
# Accuracy at step 11660: 0.3125
# Accuracy at step 11670: 0.4375
# Accuracy at step 11680: 0.4375
# Accuracy at step 11690: 0.4375
# Accuracy at step 11700: 0.5625
# Accuracy at step 11710: 0.5
# Accuracy at step 11720: 0.375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 11730: 0.6875
# Accuracy at step 11740: 0.625
# Accuracy at step 11750: 0.5
# Accuracy at step 11760: 0.375
# Accuracy at step 11770: 0.375
# Accuracy at step 11780: 0.625
# Accuracy at step 11790: 0.375
# Accuracy at step 11800: 0.375
# Accuracy at step 11810: 0.375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 11820: 0.4375
# Accuracy at step 11830: 0.625
# Accuracy at step 11840: 0.5625
# Accuracy at step 11850: 0.375
# Accuracy at step 11860: 0.4375
# Accuracy at step 11870: 0.4375
# Accuracy at step 11880: 0.25
# Accuracy at step 11890: 0.625
# Accuracy at step 11900: 0.5
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 11910: 0.375
# Accuracy at step 11920: 0.3125
# Accuracy at step 11930: 0.4375
# Accuracy at step 11940: 0.5
# Accuracy at step 11950: 0.5625
# Accuracy at step 11960: 0.8125
# Accuracy at step 11970: 0.6875
# Accuracy at step 11980: 0.5625
# Accuracy at step 11990: 0.6875
# Accuracy at step 12000: 0.625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 12010: 0.5
# Accuracy at step 12020: 0.3125
# Accuracy at step 12030: 0.5625
# Accuracy at step 12040: 0.5
# Accuracy at step 12050: 0.5625
# Accuracy at step 12060: 0.625
# Accuracy at step 12070: 0.5625
# Accuracy at step 12080: 0.5
# Accuracy at step 12090: 0.5
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 12100: 0.625
# Accuracy at step 12110: 0.5
# Accuracy at step 12120: 0.5
# Accuracy at step 12130: 0.4375
# Accuracy at step 12140: 0.5625
# Accuracy at step 12150: 0.625
# Accuracy at step 12160: 0.625
# Accuracy at step 12170: 0.5
# Accuracy at step 12180: 0.375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 12190: 0.5
# Accuracy at step 12200: 0.375
# Accuracy at step 12210: 0.5625
# Accuracy at step 12220: 0.375
# Accuracy at step 12230: 0.5625
# Accuracy at step 12240: 0.4375
# Accuracy at step 12250: 0.4375
# Accuracy at step 12260: 0.5625
# Accuracy at step 12270: 0.625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 12280: 0.6875
# Accuracy at step 12290: 0.6875
# Accuracy at step 12300: 0.4375
# Accuracy at step 12310: 0.5
# Accuracy at step 12320: 0.375
# Accuracy at step 12330: 0.3125
# Accuracy at step 12340: 0.5
# Accuracy at step 12350: 0.5625
# Accuracy at step 12360: 0.25
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 12370: 0.625
# Accuracy at step 12380: 0.375
# Accuracy at step 12390: 0.5
# Accuracy at step 12400: 0.6875
# Accuracy at step 12410: 0.5625
# Accuracy at step 12420: 0.625
# Accuracy at step 12430: 0.5
# Accuracy at step 12440: 0.5625
# Accuracy at step 12450: 0.6875
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 12460: 0.4375
# Accuracy at step 12470: 0.3125
# Accuracy at step 12480: 0.25
# Accuracy at step 12490: 0.25
# Accuracy at step 12500: 0.4375
# Accuracy at step 12510: 0.5
# Accuracy at step 12520: 0.5625
# Accuracy at step 12530: 0.6875
# Accuracy at step 12540: 0.5
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 12550: 0.625
# Accuracy at step 12560: 0.625
# Accuracy at step 12570: 0.5
# Accuracy at step 12580: 0.75
# Accuracy at step 12590: 0.3125
# Accuracy at step 12600: 0.3125
# Accuracy at step 12610: 0.3125
# Accuracy at step 12620: 0.3125
# Accuracy at step 12630: 0.4375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 12640: 0.5625
# Accuracy at step 12650: 0.5625
# Accuracy at step 12660: 0.5
# Accuracy at step 12670: 0.5625
# Accuracy at step 12680: 0.5
# Accuracy at step 12690: 0.25
# Accuracy at step 12700: 0.6875
# Accuracy at step 12710: 0.3125
# Accuracy at step 12720: 0.375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 12730: 0.5
# Accuracy at step 12740: 0.625
# Accuracy at step 12750: 0.375
# Accuracy at step 12760: 0.4375
# Accuracy at step 12770: 0.6875
# Accuracy at step 12780: 0.5625
# Accuracy at step 12790: 0.625
# Accuracy at step 12800: 0.5
# Accuracy at step 12810: 0.375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 12820: 0.375
# Accuracy at step 12830: 0.625
# Accuracy at step 12840: 0.375
# Accuracy at step 12850: 0.625
# Accuracy at step 12860: 0.625
# Accuracy at step 12870: 0.25
# Accuracy at step 12880: 0.4375
# Accuracy at step 12890: 0.5625
# Accuracy at step 12900: 0.75
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 12910: 0.25
# Accuracy at step 12920: 0.3125
# Accuracy at step 12930: 0.5625
# Accuracy at step 12940: 0.25
# Accuracy at step 12950: 0.5
# Accuracy at step 12960: 0.4375
# Accuracy at step 12970: 0.5
# Accuracy at step 12980: 0.5
# Accuracy at step 12990: 0.5625
# Accuracy at step 13000: 0.5
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 13010: 0.4375
# Accuracy at step 13020: 0.5625
# Accuracy at step 13030: 0.5
# Accuracy at step 13040: 0.5
# Accuracy at step 13050: 0.625
# Accuracy at step 13060: 0.4375
# Accuracy at step 13070: 0.5
# Accuracy at step 13080: 0.5625
# Accuracy at step 13090: 0.75
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 13100: 0.4375
# Accuracy at step 13110: 0.3125
# Accuracy at step 13120: 0.5625
# Accuracy at step 13130: 0.6875
# Accuracy at step 13140: 0.5
# Accuracy at step 13150: 0.6875
# Accuracy at step 13160: 0.3125
# Accuracy at step 13170: 0.5
# Accuracy at step 13180: 0.4375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 13190: 0.4375
# Accuracy at step 13200: 0.75
# Accuracy at step 13210: 0.375
# Accuracy at step 13220: 0.4375
# Accuracy at step 13230: 0.4375
# Accuracy at step 13240: 0.5625
# Accuracy at step 13250: 0.5625
# Accuracy at step 13260: 0.4375
# Accuracy at step 13270: 0.375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 13280: 0.5625
# Accuracy at step 13290: 0.375
# Accuracy at step 13300: 0.6875
# Accuracy at step 13310: 0.4375
# Accuracy at step 13320: 0.5625
# Accuracy at step 13330: 0.3125
# Accuracy at step 13340: 0.625
# Accuracy at step 13350: 0.6875
# Accuracy at step 13360: 0.4375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 13370: 0.6875
# Accuracy at step 13380: 0.3125
# Accuracy at step 13390: 0.5
# Accuracy at step 13400: 0.4375
# Accuracy at step 13410: 0.625
# Accuracy at step 13420: 0.5
# Accuracy at step 13430: 0.5
# Accuracy at step 13440: 0.5
# Accuracy at step 13450: 0.5
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 13460: 0.5625
# Accuracy at step 13470: 0.5
# Accuracy at step 13480: 0.4375
# Accuracy at step 13490: 0.5
# Accuracy at step 13500: 0.5
# Accuracy at step 13510: 0.5625
# Accuracy at step 13520: 0.75
# Accuracy at step 13530: 0.4375
# Accuracy at step 13540: 0.8125
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 13550: 0.5625
# Accuracy at step 13560: 0.4375
# Accuracy at step 13570: 0.75
# Accuracy at step 13580: 0.625
# Accuracy at step 13590: 0.5625
# Accuracy at step 13600: 0.5
# Accuracy at step 13610: 0.375
# Accuracy at step 13620: 0.625
# Accuracy at step 13630: 0.6875
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 13640: 0.5625
# Accuracy at step 13650: 0.6875
# Accuracy at step 13660: 0.5625
# Accuracy at step 13670: 0.4375
# Accuracy at step 13680: 0.375
# Accuracy at step 13690: 0.5625
# Accuracy at step 13700: 0.375
# Accuracy at step 13710: 0.3125
# Accuracy at step 13720: 0.3125
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 13730: 0.625
# Accuracy at step 13740: 0.5625
# Accuracy at step 13750: 0.4375
# Accuracy at step 13760: 0.5625
# Accuracy at step 13770: 0.25
# Accuracy at step 13780: 0.625
# Accuracy at step 13790: 0.5
# Accuracy at step 13800: 0.5625
# Accuracy at step 13810: 0.6875
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 13820: 0.4375
# Accuracy at step 13830: 0.5
# Accuracy at step 13840: 0.5
# Accuracy at step 13850: 0.5
# Accuracy at step 13860: 0.375
# Accuracy at step 13870: 0.5
# Accuracy at step 13880: 0.4375
# Accuracy at step 13890: 0.5625
# Accuracy at step 13900: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 13910: 0.4375
# Accuracy at step 13920: 0.4375
# Accuracy at step 13930: 0.625
# Accuracy at step 13940: 0.625
# Accuracy at step 13950: 0.5
# Accuracy at step 13960: 0.625
# Accuracy at step 13970: 0.5
# Accuracy at step 13980: 0.375
# Accuracy at step 13990: 0.375
# Accuracy at step 14000: 0.625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 14010: 0.5625
# Accuracy at step 14020: 0.4375
# Accuracy at step 14030: 0.5625
# Accuracy at step 14040: 0.5625
# Accuracy at step 14050: 0.625
# Accuracy at step 14060: 0.4375
# Accuracy at step 14070: 0.5
# Accuracy at step 14080: 0.375
# Accuracy at step 14090: 0.6875
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 14100: 0.375
# Accuracy at step 14110: 0.625
# Accuracy at step 14120: 0.625
# Accuracy at step 14130: 0.375
# Accuracy at step 14140: 0.5
# ...
# Accuracy at step 17250: 0.5
# Accuracy at step 17260: 0.375
# Accuracy at step 17270: 0.125
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 17280: 0.3125
# Accuracy at step 17290: 0.25
# Accuracy at step 17300: 0.4375
# Accuracy at step 17310: 0.5625
# Accuracy at step 17320: 0.625
# Accuracy at step 17330: 0.625
# Accuracy at step 17340: 0.5
# Accuracy at step 17350: 0.6875
# Accuracy at step 17360: 0.6875
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 17370: 0.4375
# Accuracy at step 17380: 0.625
# Accuracy at step 17390: 0.5
# Accuracy at step 17400: 0.5
# Accuracy at step 17410: 0.3125
# Accuracy at step 17420: 0.4375
# Accuracy at step 17430: 0.5625
# Accuracy at step 17440: 0.5
# Accuracy at step 17450: 0.5
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 17460: 0.5
# Accuracy at step 17470: 0.5625
# Accuracy at step 17480: 0.75
# Accuracy at step 17490: 0.5
# Accuracy at step 17500: 0.3125
# Accuracy at step 17510: 0.4375
# Accuracy at step 17520: 0.6875
# Accuracy at step 17530: 0.5
# Accuracy at step 17540: 0.75
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 17550: 0.4375
# Accuracy at step 17560: 0.6875
# Accuracy at step 17570: 0.625
# Accuracy at step 17580: 0.375
# Accuracy at step 17590: 0.4375
# Accuracy at step 17600: 0.5625
# Accuracy at step 17610: 0.5625
# Accuracy at step 17620: 0.375
# Accuracy at step 17630: 0.4375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 17640: 0.4375
# Accuracy at step 17650: 0.625
# Accuracy at step 17660: 0.4375
# Accuracy at step 17670: 0.3125
# Accuracy at step 17680: 0.625
# Accuracy at step 17690: 0.4375
# Accuracy at step 17700: 0.625
# Accuracy at step 17710: 0.5625
# Accuracy at step 17720: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 17730: 0.375
# Accuracy at step 17740: 0.5
# Accuracy at step 17750: 0.5
# Accuracy at step 17760: 0.5
# Accuracy at step 17770: 0.625
# Accuracy at step 17780: 0.5625
# Accuracy at step 17790: 0.5
# Accuracy at step 17800: 0.5
# Accuracy at step 17810: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 17820: 0.5625
# Accuracy at step 17830: 0.6875
# Accuracy at step 17840: 0.25
# Accuracy at step 17850: 0.375
# Accuracy at step 17860: 0.4375
# Accuracy at step 17870: 0.3125
# Accuracy at step 17880: 0.375
# Accuracy at step 17890: 0.8125
# Accuracy at step 17900: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 17910: 0.375
# Accuracy at step 17920: 0.375
# Accuracy at step 17930: 0.5
# Accuracy at step 17940: 0.625
# Accuracy at step 17950: 0.25
# Accuracy at step 17960: 0.375
# Accuracy at step 17970: 0.4375
# Accuracy at step 17980: 0.4375
# Accuracy at step 17990: 0.625
# Accuracy at step 18000: 0.375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 18010: 0.5625
# Accuracy at step 18020: 0.375
# Accuracy at step 18030: 0.6875
# Accuracy at step 18040: 0.5625
# Accuracy at step 18050: 0.375
# Accuracy at step 18060: 0.5
# Accuracy at step 18070: 0.4375
# Accuracy at step 18080: 0.6875
# Accuracy at step 18090: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 18100: 0.4375
# Accuracy at step 18110: 0.5
# Accuracy at step 18120: 0.6875
# Accuracy at step 18130: 0.375
# Accuracy at step 18140: 0.3125
# Accuracy at step 18150: 0.4375
# Accuracy at step 18160: 0.5
# Accuracy at step 18170: 0.5625
# Accuracy at step 18180: 0.625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 18190: 0.375
# Accuracy at step 18200: 0.6875
# Accuracy at step 18210: 0.8125
# Accuracy at step 18220: 0.6875
# Accuracy at step 18230: 0.375
# Accuracy at step 18240: 0.375
# Accuracy at step 18250: 0.4375
# Accuracy at step 18260: 0.25
# Accuracy at step 18270: 0.75
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 18280: 0.4375
# Accuracy at step 18290: 0.625
# Accuracy at step 18300: 0.5625
# Accuracy at step 18310: 0.5625
# Accuracy at step 18320: 0.4375
# Accuracy at step 18330: 0.4375
# Accuracy at step 18340: 0.625
# Accuracy at step 18350: 0.4375
# Accuracy at step 18360: 0.3125
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 18370: 0.5
# Accuracy at step 18380: 0.875
# Accuracy at step 18390: 0.3125
# Accuracy at step 18400: 0.25
# Accuracy at step 18410: 0.4375
# Accuracy at step 18420: 0.5625
# Accuracy at step 18430: 0.4375
# Accuracy at step 18440: 0.4375
# Accuracy at step 18450: 0.625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 18460: 0.8125
# Accuracy at step 18470: 0.5625
# Accuracy at step 18480: 0.4375
# Accuracy at step 18490: 0.5
# Accuracy at step 18500: 0.4375
# Accuracy at step 18510: 0.625
# Accuracy at step 18520: 0.6875
# Accuracy at step 18530: 0.375
# Accuracy at step 18540: 0.4375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 18550: 0.3125
# Accuracy at step 18560: 0.5
# Accuracy at step 18570: 0.5625
# Accuracy at step 18580: 0.4375
# Accuracy at step 18590: 0.25
# Accuracy at step 18600: 0.625
# Accuracy at step 18610: 0.625
# Accuracy at step 18620: 0.4375
# Accuracy at step 18630: 0.3125
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 18640: 0.8125
# Accuracy at step 18650: 0.5
# Accuracy at step 18660: 0.5625
# Accuracy at step 18670: 0.4375
# Accuracy at step 18680: 0.5
# Accuracy at step 18690: 0.375
# Accuracy at step 18700: 0.5
# Accuracy at step 18710: 0.5
# Accuracy at step 18720: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 18730: 0.75
# Accuracy at step 18740: 0.4375
# Accuracy at step 18750: 0.5625
# Accuracy at step 18760: 0.75
# Accuracy at step 18770: 0.75
# Accuracy at step 18780: 0.5
# Accuracy at step 18790: 0.4375
# Accuracy at step 18800: 0.625
# Accuracy at step 18810: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 18820: 0.5
# Accuracy at step 18830: 0.375
# Accuracy at step 18840: 0.5
# Accuracy at step 18850: 0.5625
# Accuracy at step 18860: 0.625
# Accuracy at step 18870: 0.5
# Accuracy at step 18880: 0.5625
# Accuracy at step 18890: 0.625
# Accuracy at step 18900: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 18910: 0.625
# Accuracy at step 18920: 0.25
# Accuracy at step 18930: 0.4375
# Accuracy at step 18940: 0.4375
# Accuracy at step 18950: 0.5
# Accuracy at step 18960: 0.625
# Accuracy at step 18970: 0.625
# Accuracy at step 18980: 0.4375
# Accuracy at step 18990: 0.5
# Accuracy at step 19000: 0.4375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 19010: 0.625
# Accuracy at step 19020: 0.75
# Accuracy at step 19030: 0.5
# Accuracy at step 19040: 0.5
# Accuracy at step 19050: 0.5625
# Accuracy at step 19060: 0.5625
# Accuracy at step 19070: 0.625
# Accuracy at step 19080: 0.5
# Accuracy at step 19090: 0.25
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 19100: 0.5625
# Accuracy at step 19110: 0.5625
# Accuracy at step 19120: 0.625
# Accuracy at step 19130: 0.4375
# Accuracy at step 19140: 0.4375
# Accuracy at step 19150: 0.5
# Accuracy at step 19160: 0.5
# Accuracy at step 19170: 0.5
# Accuracy at step 19180: 0.6875
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 19190: 0.5625
# Accuracy at step 19200: 0.4375
# Accuracy at step 19210: 0.625
# Accuracy at step 19220: 0.5
# Accuracy at step 19230: 0.1875
# Accuracy at step 19240: 0.375
# Accuracy at step 19250: 0.5625
# Accuracy at step 19260: 0.4375
# Accuracy at step 19270: 0.6875
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 19280: 0.4375
# Accuracy at step 19290: 0.6875
# Accuracy at step 19300: 0.3125
# Accuracy at step 19310: 0.5
# Accuracy at step 19320: 0.5
# Accuracy at step 19330: 0.375
# Accuracy at step 19340: 0.875
# Accuracy at step 19350: 0.625
# Accuracy at step 19360: 0.625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 19370: 0.375
# Accuracy at step 19380: 0.625
# Accuracy at step 19390: 0.5
# Accuracy at step 19400: 0.375
# Accuracy at step 19410: 0.625
# Accuracy at step 19420: 0.5625
# Accuracy at step 19430: 0.5
# Accuracy at step 19440: 0.625
# Accuracy at step 19450: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 19460: 0.4375
# Accuracy at step 19470: 0.4375
# Accuracy at step 19480: 0.6875
# Accuracy at step 19490: 0.5
# Accuracy at step 19500: 0.5
# Accuracy at step 19510: 0.25
# Accuracy at step 19520: 0.5625
# Accuracy at step 19530: 0.5
# Accuracy at step 19540: 0.5625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 19550: 0.3125
# Accuracy at step 19560: 0.5
# Accuracy at step 19570: 0.625
# Accuracy at step 19580: 0.375
# Accuracy at step 19590: 0.625
# Accuracy at step 19600: 0.1875
# Accuracy at step 19610: 0.5
# Accuracy at step 19620: 0.75
# Accuracy at step 19630: 0.5
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 19640: 0.5
# Accuracy at step 19650: 0.625
# Accuracy at step 19660: 0.5625
# Accuracy at step 19670: 0.5
# Accuracy at step 19680: 0.4375
# Accuracy at step 19690: 0.6875
# Accuracy at step 19700: 0.5625
# Accuracy at step 19710: 0.375
# Accuracy at step 19720: 0.375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 19730: 0.6875
# Accuracy at step 19740: 0.4375
# Accuracy at step 19750: 0.5625
# Accuracy at step 19760: 0.5625
# Accuracy at step 19770: 0.625
# Accuracy at step 19780: 0.375
# Accuracy at step 19790: 0.4375
# Accuracy at step 19800: 0.4375
# Accuracy at step 19810: 0.25
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 19820: 0.5625
# Accuracy at step 19830: 0.5625
# Accuracy at step 19840: 0.25
# Accuracy at step 19850: 0.625
# Accuracy at step 19860: 0.5625
# Accuracy at step 19870: 0.5
# Accuracy at step 19880: 0.375
# Accuracy at step 19890: 0.3125
# Accuracy at step 19900: 0.5
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 19910: 0.375
# Accuracy at step 19920: 0.625
# Accuracy at step 19930: 0.375
# Accuracy at step 19940: 0.4375
# Accuracy at step 19950: 0.4375
# Accuracy at step 19960: 0.5
# Accuracy at step 19970: 0.5625
# Accuracy at step 19980: 0.5625
# Accuracy at step 19990: 0.3125
# Accuracy at step 20000: 0.6875
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 20010: 0.625
# Accuracy at step 20020: 0.4375
# Accuracy at step 20030: 0.4375
# Accuracy at step 20040: 0.5625
# Accuracy at step 20050: 0.375
# Accuracy at step 20060: 0.375
# Accuracy at step 20070: 0.5
# Accuracy at step 20080: 0.4375
# Accuracy at step 20090: 0.4375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 20100: 0.4375
# Accuracy at step 20110: 0.75
# Accuracy at step 20120: 0.5
# Accuracy at step 20130: 0.5
# Accuracy at step 20140: 0.375
# Accuracy at step 20150: 0.375
# Accuracy at step 20160: 0.8125
# Accuracy at step 20170: 0.5
# Accuracy at step 20180: 0.4375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 20190: 0.5
# Accuracy at step 20200: 0.5625
# Accuracy at step 20210: 0.375
# Accuracy at step 20220: 0.5
# Accuracy at step 20230: 0.5
# Accuracy at step 20240: 0.625
# Accuracy at step 20250: 0.4375
# Accuracy at step 20260: 0.625
# Accuracy at step 20270: 0.625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 20280: 0.25
# Accuracy at step 20290: 0.5
# Accuracy at step 20300: 0.4375
# Accuracy at step 20310: 0.5
# Accuracy at step 20320: 0.5
# Accuracy at step 20330: 0.5
# Accuracy at step 20340: 0.625
# Accuracy at step 20350: 0.5
# Accuracy at step 20360: 0.6875
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 20370: 0.5625
# Accuracy at step 20380: 0.4375
# Accuracy at step 20390: 0.4375
# Accuracy at step 20400: 0.4375
# Accuracy at step 20410: 0.625
# Accuracy at step 20420: 0.5625
# Accuracy at step 20430: 0.3125
# Accuracy at step 20440: 0.5
# Accuracy at step 20450: 0.625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 20460: 0.875
# Accuracy at step 20470: 0.5625
# Accuracy at step 20480: 0.75
# Accuracy at step 20490: 0.625
# Accuracy at step 20500: 0.375
# Accuracy at step 20510: 0.625
# Accuracy at step 20520: 0.5
# Accuracy at step 20530: 0.5
# Accuracy at step 20540: 0.6875
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 20550: 0.75
# Accuracy at step 20560: 0.4375
# Accuracy at step 20570: 0.5625
# Accuracy at step 20580: 0.3125
# Accuracy at step 20590: 0.4375
# Accuracy at step 20600: 0.375
# Accuracy at step 20610: 0.5
# Accuracy at step 20620: 0.625
# Accuracy at step 20630: 0.4375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 20640: 0.75
# Accuracy at step 20650: 0.5625
# Accuracy at step 20660: 0.8125
# Accuracy at step 20670: 0.4375
# Accuracy at step 20680: 0.3125
# Accuracy at step 20690: 0.5
# Accuracy at step 20700: 0.625
# Accuracy at step 20710: 0.4375
# Accuracy at step 20720: 0.4375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 20730: 0.4375
# Accuracy at step 20740: 0.5625
# Accuracy at step 20750: 0.5
# Accuracy at step 20760: 0.5625
# Accuracy at step 20770: 0.375
# Accuracy at step 20780: 0.4375
# Accuracy at step 20790: 0.5625
# Accuracy at step 20800: 0.5625
# Accuracy at step 20810: 0.5
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 20820: 0.5625
# Accuracy at step 20830: 0.375
# Accuracy at step 20840: 0.5625
# Accuracy at step 20850: 0.625
# Accuracy at step 20860: 0.625
# Accuracy at step 20870: 0.3125
# Accuracy at step 20880: 0.625
# Accuracy at step 20890: 0.625
# Accuracy at step 20900: 0.375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 20910: 0.375
# Accuracy at step 20920: 0.625
# Accuracy at step 20930: 0.4375
# Accuracy at step 20940: 0.5625
# Accuracy at step 20950: 0.5625
# Accuracy at step 20960: 0.625
# Accuracy at step 20970: 0.4375
# Accuracy at step 20980: 0.4375
# Accuracy at step 20990: 0.5625
# Accuracy at step 21000: 0.5
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 21010: 0.4375
# Accuracy at step 21020: 0.4375
# Accuracy at step 21030: 0.5
# Accuracy at step 21040: 0.5
# Accuracy at step 21050: 0.5
# Accuracy at step 21060: 0.25
# Accuracy at step 21070: 0.375
# Accuracy at step 21080: 0.6875
# Accuracy at step 21090: 0.625
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 21100: 0.6875
# Accuracy at step 21110: 0.375
# Accuracy at step 21120: 0.375
# Accuracy at step 21130: 0.5
# Accuracy at step 21140: 0.5
# Accuracy at step 21150: 0.5625
# Accuracy at step 21160: 0.5625
# Accuracy at step 21170: 0.5625
# Accuracy at step 21180: 0.5
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 21190: 0.375
# Accuracy at step 21200: 0.625
# Accuracy at step 21210: 0.375
# Accuracy at step 21220: 0.5
# Accuracy at step 21230: 0.375
# Accuracy at step 21240: 0.5
# Accuracy at step 21250: 0.625
# Accuracy at step 21260: 0.4375
# Accuracy at step 21270: 0.4375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 21280: 0.4375
# Accuracy at step 21290: 0.5625
# Accuracy at step 21300: 0.5
# Accuracy at step 21310: 0.4375
# Accuracy at step 21320: 0.625
# Accuracy at step 21330: 0.5625
# Accuracy at step 21340: 0.625
# Accuracy at step 21350: 0.5
# Accuracy at step 21360: 0.6875
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 21370: 0.3125
# Accuracy at step 21380: 0.4375
# Accuracy at step 21390: 0.375
# Accuracy at step 21400: 0.625
# Accuracy at step 21410: 0.5
# Accuracy at step 21420: 0.625
# Accuracy at step 21430: 0.75
# Accuracy at step 21440: 0.4375
# Accuracy at step 21450: 0.3125
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 21460: 0.5
# Accuracy at step 21470: 0.3125
# Accuracy at step 21480: 0.6875
# Accuracy at step 21490: 0.4375
# Accuracy at step 21500: 0.625
# Accuracy at step 21510: 0.5
# Accuracy at step 21520: 0.5625
# Accuracy at step 21530: 0.375
# Accuracy at step 21540: 0.875
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 21550: 0.6875
# Accuracy at step 21560: 0.4375
# Accuracy at step 21570: 0.625
# Accuracy at step 21580: 0.4375
# Accuracy at step 21590: 0.5
# Accuracy at step 21600: 0.5625
# Accuracy at step 21610: 0.625
# Accuracy at step 21620: 0.5
# Accuracy at step 21630: 0.3125
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 21640: 0.6875
# Accuracy at step 21650: 0.6875
# Accuracy at step 21660: 0.6875
# Accuracy at step 21670: 0.625
# Accuracy at step 21680: 0.5
# Accuracy at step 21690: 0.5
# Accuracy at step 21700: 0.875
# Accuracy at step 21710: 0.5625
# Accuracy at step 21720: 0.375
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 21730: 0.5
# Accuracy at step 21740: 0.5
# Accuracy at step 21750: 0.6875
# Accuracy at step 21760: 0.4375
# Accuracy at step 21770: 0.5625
# Accuracy at step 21780: 0.625
# Accuracy at step 21790: 0.5
# Accuracy at step 21800: 0.375
# Accuracy at step 21810: 0.5
# Model saved in file: ./save_ks/model.ckpt
# Accuracy at step 21820: 0.6875
# Accuracy at step 21830: 0.5625
# Accuracy at step 21840: 0.5
# Accuracy at step 21850: 0.375

# %% [raw]
# gen_image()
